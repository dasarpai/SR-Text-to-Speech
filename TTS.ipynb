# %%
#https://towardsdatascience.com/easy-text-to-speech-with-python-bfb34250036e

# %%
# !pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.1.1-py3-none-any.whl (25 kB)
# Collecting gtts-token>=1.1.3
#   Downloading gTTS-token-1.1.3.tar.gz (3.4 kB)
# Requirement already satisfied: six in d:\users\admin\anaconda3\lib\site-packages (from gtts) (1.12.0)
# Requirement already satisfied: beautifulsoup4 in d:\users\admin\anaconda3\lib\site-packages (from gtts) (4.6.3)
# Requirement already satisfied: click in d:\users\admin\anaconda3\lib\site-packages (from gtts) (6.7)
# Requirement already satisfied: requests in d:\users\admin\anaconda3\lib\site-packages (from gtts) (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in d:\users\admin\anaconda3\lib\site-packages (from requests->gtts) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\users\admin\anaconda3\lib\site-packages (from requests->gtts) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\users\admin\anaconda3\lib\site-packages (from requests->gtts) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\admin\anaconda3\lib\site-packages (from requests->gtts) (2020.4.5.1)
# Building wheels for collected packages: gtts-token
#   Building wheel for gtts-token (setup.py): started
#   Building wheel for gtts-token (setup.py): finished with status 'done'
#   Created wheel for gtts-token: filename=gTTS_token-1.1.3-py3-none-any.whl size=4102 sha256=19a779386e49bbeed28eb5ef5de675b0c24111484d0c90f521c2e83b3d39f73b
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\c1\78\25\81270af5521d88ea8db7da5d4f64872673976eb9692bcb0c13
# Successfully built gtts-token
# Installing collected packages: gtts-token, gtts
# Successfully installed gtts-2.1.1 gtts-token-1.1.3
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the 'd:\users\admin\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from gtts import gTTS 
import os

# %%
text = "Global warming is the long-term rise in the average temperature of the Earth’s climate system"
text = "Have you ever seen a person Who hires someone else to love his/her spouse and children?"
language = 'en'
speech = gTTS(text = text, lang = language, slow = False)

# %%
speech.save('text.mp3')

# %% [markdown]
# The output of the above program saved as text.mp3 file. Mp3 file should be a voice saying, 'Global warming is the long-term rise in the average temperature of the Earth’s climate system'

# %%
file = open("draft.txt", "r").read().replace("\n", " ")

# %%
speech = gTTS(text = str(file), lang = language, slow = False)

# %%
speech.save('startvoice.mp3')

os.system("startvoice.mp3")
# Out:
# 0
